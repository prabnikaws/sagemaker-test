# %%
# %%pyspark emr-eks.plume-data-domain-2-profile1-compute
# from pyspark.sql import Row
#
# data = [
#     Row(id=1, name="Alice", region="NORTH", amount=150.00),
#     Row(id=2, name="Bob", region="SOUTH", amount=275.50),
#     Row(id=3, name="Charlie", region="EAST", amount=89.99),
#     Row(id=4, name="Diana", region="WEST", amount=432.00),
#     Row(id=5, name="Eve", region="NORTH", amount=67.25)
# ]
# df = spark.createDataFrame(data)
# df.show()
# df.groupBy("region").agg({"amount": "sum"}).show()
# Out:
# Executing for connection type: SPARK_EMR_EKS, connection name: emr-eks.plume-data-domain-2-profile1-compute
# Create session for connection: emr-eks.plume-data-domain-2-profile1-compute
# Starting Spark application
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Compute details - Virtual Cluster Id: 39rpa77zrjql4xbeug56v9rh1, Runtime role: arn:aws:iam::048408302137:role/datazone_usr_role_dihrym8xu6of8n_bwkagkxqc4panb
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Session created for connection: emr-eks.plume-data-domain-2-profile1-compute.
# ...

# %%
# %%pyspark emr-eks.plume-data-domain-2-profile1-compute
