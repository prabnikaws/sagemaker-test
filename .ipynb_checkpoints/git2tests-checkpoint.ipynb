# %%
# %%pyspark emr-eks.plume-data-domain-2-profile1-compute
# from pyspark.sql import Row
# from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType
#
# # Create sample data
# data = [
#     Row(id=1, name="Alice", department="Engineering", salary=75000),
#     Row(id=2, name="Bob", department="Marketing", salary=65000),
#     Row(id=3, name="Charlie", department="Engineering", salary=80000),
#     Row(id=4, name="Diana", department="Sales", salary=70000),
#     Row(id=5, name="Eve", department="Marketing", salary=72000)
# ]
#
# df = spark.createDataFrame(data)
# df.show()

# %%
# %%pyspark emr-eks.plume-data-domain-2-profile1-compute
